# %% [markdown]
# <a href="https://colab.research.google.com/github/RejaulBSSE1324/SPL3/blob/main/spl3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install and Import

# %%
# !pip install alphashape
import numpy as np
import alphashape
from shapely.geometry import MultiPolygon, Polygon
import plotly.graph_objects as go
from skimage.measure import approximate_polygon
from scipy.interpolate import CubicSpline
from scipy.spatial.distance import cdist
import numpy as np
from scipy.spatial import cKDTree
import math
import matplotlib.pyplot as plt

# %% [markdown]
# # Mount Drive and Load Data

# %%
from google.colab import drive
drive.mount('/content/drive')

# Load your .pts data
file_path = '/content/drive/MyDrive/02.building roof lidar/Building Boundary/Toronto/roof/build02.pts'
data = np.loadtxt(file_path, usecols=(0, 1, 2), skiprows=0)

# Extract X, Y, Z coordinates
x, y, z = data[:, 0], data[:, 1], data[:, 2]
points_3d = np.column_stack((x, y, z))
points_2d = np.column_stack((x, y))

print(f"Loaded {len(points_2d)} points")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-176/293708120.py in <cell line: 0>()
#       4 # Load your .pts data
#       5 file_path = '/content/drive/MyDrive/02.building roof lidar/Building Boundary/Toronto/roof/build02.pts'
# ----> 6 data = np.loadtxt(file_path, usecols=(0, 1, 2), skiprows=0)
#       7
#       8 # Extract X, Y, Z coordinates
#
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_npyio_impl.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1379         delimiter = delimiter.decode('latin1')
#    1380
# -> 1381     arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
# ...

# %% [markdown]
# **--------------------------Visualize 2D-------------------**

# %%
def visualize_2d_points(points_2d, title='2D Points Visualization'):
    """Visualize 2D points using scatter plot"""
    points_2d = np.array(points_2d)
    x = points_2d[:, 0]
    y = points_2d[:, 1]

    trace = go.Scatter(
        x=x, y=y,
        mode='markers',
        marker=dict(size=3, color='blue', opacity=0.8)
    )

    layout = go.Layout(
        title=title,
        xaxis_title='X',
        yaxis_title='Y',
        autosize=True
    )

    fig = go.Figure(data=[trace], layout=layout)
    fig.show()

def visualize_overlay(points_2d, contour, title='Contour Overlay'):
    """Visualize original points with contour overlay"""
    fig = go.Figure()

    # Original building points
    fig.add_trace(go.Scatter(
        x=points_2d[:, 0], y=points_2d[:, 1],
        mode='markers',
        marker=dict(size=2, color='lightgray'),
        name='Building Roof Points'
    ))

    # Contour
    fig.add_trace(go.Scatter(
        x=contour[:, 0], y=contour[:, 1],
        mode='lines+markers',
        marker=dict(size=4, color='red'),
        line=dict(width=2, color='red'),
        name='Extracted Contour'
    ))

    fig.update_layout(
        title=title,
        xaxis_title='X',
        yaxis_title='Y',
        autosize=True
    )
    fig.show()

# Visualize original points
visualize_2d_points(points_2d, 'Original Building Point Cloud')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Calculate Average Point Spacing (k=80) (Paper: Section 2.1.2 )**

# %%
def calculate_average_point_spacing(points_2d, k=80):
    """
    Calculate average point spacing using k anchor points.
    Paper specifies k=80 for stability.
    """
    points_2d = np.array(points_2d)
    k = min(k, len(points_2d))

    tree = cKDTree(points_2d)

    # Randomly select k anchor points
    indices = np.random.choice(points_2d.shape[0], k, replace=False)
    anchor_points = points_2d[indices]

    # Find nearest neighbor for each anchor (k=2 because first is itself)
    distances, _ = tree.query(anchor_points, k=2)
    nearest_distances = distances[:, 1]

    avg_spacing = np.mean(nearest_distances)
    return avg_spacing

# Calculate average spacing
avg_spacing = calculate_average_point_spacing(points_2d, k=80)
print(f"✓ Average point spacing (d): {avg_spacing:.4f} m")

# Calculate paper-specified parameters
W = 8 * avg_spacing  # Band width (Paper: W = 8*d)
T = 10 * avg_spacing  # Densification threshold (Paper: T = 10*d)

print(f"✓ Band width (W = 8*d): {W:.4f} m")
print(f"✓ Densification threshold (T = 10*d): {T:.4f} m")
# Out:
# ✓ Average point spacing (d): 0.1648 m
# ✓ Band width (W = 8*d): 1.3183 m
# ✓ Densification threshold (T = 10*d): 1.6478 m

# %% [markdown]
# **            Single-Direction Banding( Paper: Section 2.1.1) **

# %%
def extract_contour_single_direction(points_2d, band_width, angle=0):
    """
    Extract contour points using single-direction banding.

    Process:
    1. Rotate points to align bands with specified angle
    2. Divide into bands of width W along x-axis
    3. For each band, project points onto central axis
    4. Find two points with maximum and minimum y-coordinates
    """
    # Rotate points
    angle_rad = np.deg2rad(angle)
    cos_a, sin_a = np.cos(angle_rad), np.sin(angle_rad)
    rotation_matrix = np.array([[cos_a, -sin_a], [sin_a, cos_a]])

    rotated_points = points_2d @ rotation_matrix.T

    # Create bands along x-axis
    min_x, max_x = rotated_points[:, 0].min(), rotated_points[:, 0].max()
    bands = np.arange(min_x, max_x + band_width, band_width)

    contour_points = []

    for i in range(len(bands) - 1):
        band_left = bands[i]
        band_right = bands[i + 1]

        # Get points in this band
        mask = (rotated_points[:, 0] >= band_left) & (rotated_points[:, 0] < band_right)
        band_points_rotated = rotated_points[mask]

        if len(band_points_rotated) == 0:
            continue

        # Find two points with max and min y-coordinates (extreme points)
        min_idx = np.argmin(band_points_rotated[:, 1])
        max_idx = np.argmax(band_points_rotated[:, 1])

        # Get original point indices and add to contour
        band_indices = np.where(mask)[0]
        contour_points.append(points_2d[band_indices[min_idx]])
        if min_idx != max_idx:
            contour_points.append(points_2d[band_indices[max_idx]])

    return np.array(contour_points) if contour_points else np.empty((0, 2))

# Extract single-direction contour (0 degrees for demonstration)
single_contour = extract_contour_single_direction(points_2d, W, angle=0)
print(f"✓ Single direction (0°): {len(single_contour)} contour points extracted")

visualize_2d_points(single_contour, 'Single Direction Contour (0°)')
# Out:
# ✓ Single direction (0°): 62 contour points extracted
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Multidirectional Banding (6 directions) Paper: Section 2.1.3 - Use N₀ = 6 directions

# %%
def extract_contour_multidirectional(points_2d, band_width):
    """
    Extract contour using 6 directions as specified in paper.
    Directions: 0°, 30°, 60°, 90°, 120°, 150°

    This ensures complete coverage and prevents missing contour points
    in concave areas.
    """
    directions = [0, 30, 60, 90, 120, 150]  # Paper-specified directions
    all_contour_points = []

    print(f"Extracting contour in {len(directions)} directions...")

    for angle in directions:
        contour = extract_contour_single_direction(points_2d, band_width, angle)
        if len(contour) > 0:
            all_contour_points.append(contour)
            print(f"  {angle}°: {len(contour)} points")

    if not all_contour_points:
        return np.empty((0, 2))

    # Combine all contour points
    all_points = np.vstack(all_contour_points)

    # Remove duplicates (points may be extracted in multiple directions)
    unique_points = np.unique(np.round(all_points, decimals=6), axis=0)

    return unique_points

# Extract multidirectional contour
multi_contour = extract_contour_multidirectional(points_2d, W)
print(f"\n✓ Total unique contour points: {len(multi_contour)}")

visualize_2d_points(multi_contour, 'Multidirectional Contour (6 directions)')
# Out:
# Extracting contour in 6 directions...
#   0°: 62 points
#   30°: 101 points
#   60°: 114 points
#   90°: 111 points
#   120°: 84 points
#   150°: 37 points
#
# ✓ Total unique contour points: 277
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Optimization & Densification of Contour Points

# %% [markdown]
# **Sort Contour Points with β=240° Constraint Paper: Section 2.2.1**

# %%
def sort_contour_points_with_constraint(points, beta_degrees=240):
    """
    Sort contour points by nearest neighbor with forward direction constraint.

    Paper constraint: Use β=240° sector to prevent backward connections.
    This ensures the contour line progresses in a consistent direction.
    """
    if len(points) < 2:
        return points

    sorted_pts = [points[0]]
    remaining = list(range(1, len(points)))
    last_direction = None

    while remaining:
        current = sorted_pts[-1]

        # Calculate vectors and distances to all remaining points
        candidates = points[remaining]
        vectors = candidates - current
        distances = np.linalg.norm(vectors, axis=1)

        if last_direction is not None:
            # Calculate angles relative to last direction
            angles = np.arctan2(vectors[:, 1], vectors[:, 0])
            last_angle = np.arctan2(last_direction[1], last_direction[0])

            # Angle difference (normalized to [0, π])
            angle_diff = np.abs(angles - last_angle)
            angle_diff = np.minimum(angle_diff, 2*np.pi - angle_diff)

            # Filter by β constraint (240° = 4.189 radians)
            beta_rad = np.deg2rad(beta_degrees)
            valid_mask = angle_diff <= beta_rad

            if np.any(valid_mask):
                # Choose nearest valid point
                valid_distances = np.where(valid_mask, distances, np.inf)
                next_idx = np.argmin(valid_distances)
            else:
                # If no valid points, choose nearest
                next_idx = np.argmin(distances)
        else:
            # First connection: just choose nearest
            next_idx = np.argmin(distances)

        # Add next point and update
        next_point_idx = remaining[next_idx]
        sorted_pts.append(points[next_point_idx])
        last_direction = points[next_point_idx] - current
        remaining.pop(next_idx)

    return np.array(sorted_pts)

# Sort contour points
sorted_contour = sort_contour_points_with_constraint(multi_contour, beta_degrees=240)
print(f"✓ Sorted {len(sorted_contour)} contour points with β=240° constraint")

visualize_overlay(points_2d, sorted_contour, 'Sorted Contour ')
# Out:
# ✓ Sorted 277 contour points with β=240° constraint
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Densify Long Edges (CORRECT PAPER METHOD) Paper: Section 2.2.2**

# %%
def densify_contour_paper_method(sorted_contour, all_points_2d, threshold):
    """
    Densify contour by inserting ACTUAL points from the point cloud.

    CRITICAL DIFFERENCE from your original code:
    - Your code: Creates interpolated (fake) points
    - Paper method: Finds closest REAL points from the original point cloud

    Process:
    1. Find edges longer than threshold T
    2. Calculate midpoint of long edge
    3. Find closest NON-CONTOUR point to midpoint
    4. Insert this point into contour
    5. Repeat until all edges < T
    """
    if len(sorted_contour) < 2:
        return sorted_contour

    densified = list(sorted_contour)
    tree = cKDTree(all_points_2d)

    max_iterations = 100
    iteration = 0

    print("Densifying long edges...")

    while iteration < max_iterations:
        iteration += 1
        changed = False

        i = 0
        while i < len(densified):
            p1 = densified[i]
            p2 = densified[(i + 1) % len(densified)]

            edge_length = np.linalg.norm(p2 - p1)

            if edge_length > threshold:
                # Find midpoint of long edge
                midpoint = (p1 + p2) / 2

                # Find closest points to midpoint from original cloud
                distances, indices = tree.query(midpoint, k=20)

                best_point = None
                best_dist = np.inf

                # Find closest NON-CONTOUR point
                for dist, idx in zip(distances, indices):
                    candidate = all_points_2d[idx]

                    # Check if this point is already in contour
                    is_in_contour = any(
                        np.allclose(candidate, cp, atol=1e-6)
                        for cp in densified
                    )

                    if not is_in_contour and dist < best_dist:
                        best_point = candidate
                        best_dist = dist
                        break

                # Insert the found point
                if best_point is not None:
                    densified.insert(i + 1, best_point)
                    changed = True
                    print(f"  Iteration {iteration}: Inserted point, edge length {edge_length:.4f} → split")
                    break

            i += 1

        if not changed:
            print(f"  Converged after {iteration} iterations")
            break

    return np.array(densified)

# Densify the contour
densified_contour = densify_contour_paper_method(sorted_contour, points_2d, T)
print(f"✓ Densified contour: {len(densified_contour)} points (added {len(densified_contour) - len(sorted_contour)} points)")

visualize_overlay(points_2d, densified_contour, 'Densified Contour')
# Out:
# Densifying long edges...
#   Iteration 1: Inserted point, edge length 1.8305 → split
#   Converged after 2 iterations
# ✓ Densified contour: 278 points (added 1 points)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Remove Noise Points Paper: Section 2.2.2**

# %%
def remove_noise_points(contour_points, points_3d, avg_spacing, threshold_factor=5):
    """
    Remove noise points based on elevation difference.

    Paper method:
    1. For each contour point, find 5 nearest neighbors
    2. Calculate average elevation of these 5 neighbors
    3. If elevation difference > 5*d, consider it noise
    4. Remove noise points (e.g., parapet walls)
    """
    if len(contour_points) < 6:
        return contour_points

    threshold = threshold_factor * avg_spacing

    # Match contour points with 3D points
    tree_3d = cKDTree(points_3d[:, :2])
    contour_3d = []

    for pt_2d in contour_points:
        _, idx = tree_3d.query(pt_2d, k=1)
        contour_3d.append(points_3d[idx])

    contour_3d = np.array(contour_3d)

    filtered = []
    removed_count = 0

    for i, point in enumerate(contour_3d):
        # Find 5 nearest contour points (in 2D space)
        distances = []
        for j, other in enumerate(contour_3d):
            if i != j:
                dist = np.linalg.norm(point[:2] - other[:2])
                distances.append((dist, j))

        distances.sort()
        nearest_5_indices = [idx for _, idx in distances[:min(5, len(distances))]]

        # Calculate average elevation
        avg_z = np.mean([contour_3d[idx][2] for idx in nearest_5_indices])
        elev_diff = abs(point[2] - avg_z)

        if elev_diff < threshold:
            filtered.append(point[:2])  # Keep only X, Y
        else:
            removed_count += 1

    print(f"✓ Removed {removed_count} noise points (threshold: {threshold:.4f}m)")

    return np.array(filtered) if filtered else contour_points

# Remove noise points
final_contour = remove_noise_points(densified_contour, points_3d, avg_spacing)
print(f"✓ Final contour: {len(final_contour)} points")

visualize_overlay(points_2d, final_contour, 'Final Contour (Noise Removed)')
# Out:
# ✓ Removed 0 noise points (threshold: 0.8239m)
# ✓ Final contour: 278 points
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Close the contour**

# %%
def close_contour(points):
    """Close the contour by connecting last point to first"""
    if len(points) > 0 and not np.allclose(points[0], points[-1]):
        return np.vstack([points, points[0]])
    return points

final_contour_closed = close_contour(final_contour)
print(f"✓ Contour closed: {len(final_contour_closed)} points")

visualize_overlay(points_2d, final_contour_closed, 'Final Closed Contour')
# Out:
# ✓ Contour closed: 279 points
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Summary Statistics

# %%
print("\n" + "="*60)
print("EXTRACTION SUMMARY")
print("="*60)
print(f"Input points:              {len(points_2d)}")
print(f"Average spacing (d):       {avg_spacing:.4f} m")
print(f"Band width (W = 8*d):      {W:.4f} m")
print(f"Threshold (T = 10*d):      {T:.4f} m")
print(f"\nExtraction stages:")
print(f"  Single direction (0°):   {len(single_contour)} points")
print(f"  Multi-direction (6×):    {len(multi_contour)} points")
print(f"  After sorting:           {len(sorted_contour)} points")
print(f"  After densification:     {len(densified_contour)} points")
print(f"  After noise removal:     {len(final_contour)} points")
print(f"  Final closed contour:    {len(final_contour_closed)} points")
print("="*60)
# Out:
# ...
# EXTRACTION SUMMARY
# ...
# Input points:              9572
# Average spacing (d):       0.1648 m
# Band width (W = 8*d):      1.3183 m
# Threshold (T = 10*d):      1.6478 m
#
# Extraction stages:
#   Single direction (0°):   62 points
#   Multi-direction (6×):    277 points
#   After sorting:           277 points
#   After densification:     278 points
#   After noise removal:     278 points
#   Final closed contour:    279 points
# ...

# %% [markdown]
# # Compare Methods

# %%
def visualize_comparison(points_2d, stages):
    """Visualize all extraction stages for comparison"""
    fig = go.Figure()

    # Original points
    fig.add_trace(go.Scatter(
        x=points_2d[:, 0], y=points_2d[:, 1],
        mode='markers',
        marker=dict(size=2, color='lightgray', opacity=0.5),
        name='Original Points'
    ))

    colors = ['orange', 'blue', 'green', 'purple', 'red']
    stage_names = ['Single Dir', 'Multi Dir', 'Sorted', 'Densified', 'Final']

    for i, (stage, color, name) in enumerate(zip(stages, colors, stage_names)):
        if len(stage) > 0:
            fig.add_trace(go.Scatter(
                x=stage[:, 0], y=stage[:, 1],
                mode='lines+markers',
                marker=dict(size=3, color=color),
                line=dict(width=1, color=color),
                name=name,
                visible='legendonly' if i < len(stages)-1 else True
            ))

    fig.update_layout(
        title='Building Contour Extraction - All Stages',
        xaxis_title='X (m)',
        yaxis_title='Y (m)',
        hovermode='closest',
        legend=dict(x=0, y=1)
    )

    fig.show()

stages = [single_contour, multi_contour, sorted_contour, densified_contour, final_contour_closed]
visualize_comparison(points_2d, stages)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# ============================================================================
# Cell C1: Install alphashape (skip if already installed)
# ============================================================================
# !pip install alphashape shapely --quiet

# %%
# ============================================================================
# Cell C2: Alpha-Shape Helper Functions
# ============================================================================
import alphashape
import numpy as np
from shapely.geometry import Polygon, MultiPolygon
import plotly.graph_objects as go
from plotly.subplots import make_subplots


def extract_alpha_shape(points_2d, alpha_value):
    """
    Extract alpha-shape contour from 2D points.

    Parameters
    ----------
    points_2d  : np.ndarray  (N, 2)
    alpha_value: float  — alpha parameter for alphashape library.
                 0     → convex hull
                 small → concave / detailed
                 large → very detailed / may fragment

    Returns
    -------
    np.ndarray (M, 2)  — exterior contour coordinates (closed)
    """
    shape = alphashape.alphashape(points_2d, alpha_value)

    if shape is None or shape.is_empty:
        print(f"  ⚠️  alpha={alpha_value:.4f} → empty shape, try a smaller alpha.")
        return np.empty((0, 2))

    # If MultiPolygon, take the largest polygon
    if isinstance(shape, MultiPolygon):
        shape = max(shape.geoms, key=lambda g: g.area)

    coords = np.array(shape.exterior.coords)
    return coords


def compute_polygon_area(contour):
    """Shoelace formula for polygon area (m²)."""
    if len(contour) < 3:
        return 0.0
    x, y = contour[:, 0], contour[:, 1]
    return 0.5 * abs(np.dot(x, np.roll(y, -1)) - np.dot(y, np.roll(x, -1)))


print("✓ Alpha-shape helpers loaded.")
# Out:
# ✓ Alpha-shape helpers loaded.

# %%
# ============================================================================
# Cell C3: Compute Alpha Parameters
# ============================================================================
# Alpha values derived from average point spacing (d), consistent with
# Wang et al. (2024) parameter conventions:
#
#  • alpha_4d       = 4  × d   →  "Alpha-Shape (4d)"
#    Same scale as band width W = 8d; captures fine roof detail.
#
#  • alpha_ca_93_4d = 93 × 4d  →  "Ca-Alpha (93×4d)"
#    Large alpha → smoother, more convex-like shape.
#    Useful as an upper-bound comparison (coarse approximation).
#
# NOTE: In the alphashape library, alpha=0 gives the convex hull;
#       increasing alpha produces more concave/detailed shapes.

alpha_4d       = 4  * avg_spacing          # e.g. ≈ 0.60 m for build10
alpha_ca_93_4d = 93 * 4 * avg_spacing      # e.g. ≈ 55.6 m for build10

print(f"Average spacing    d         : {avg_spacing:.4f} m")
print(f"Alpha-Shape  alpha = 4d      : {alpha_4d:.4f} m")
print(f"Ca-Alpha     alpha = 93×4d   : {alpha_ca_93_4d:.4f} m")
print()

# ── Extract alpha-shape contours ─────────────────────────────────────────────
print("Extracting Alpha-Shape (4d) ...")
contour_alpha_4d = extract_alpha_shape(points_2d, alpha_4d)
area_alpha_4d    = compute_polygon_area(contour_alpha_4d)
print(f"  → {len(contour_alpha_4d)} contour points | Area = {area_alpha_4d:.2f} m²")

print("Extracting Ca-Alpha (93×4d) ...")
contour_ca_93_4d = extract_alpha_shape(points_2d, alpha_ca_93_4d)
area_ca_93_4d    = compute_polygon_area(contour_ca_93_4d)
print(f"  → {len(contour_ca_93_4d)} contour points | Area = {area_ca_93_4d:.2f} m²")

# ── Reference: your method ───────────────────────────────────────────────────
area_your_method = compute_polygon_area(final_contour_closed)
print()
print(f"Your Method (Multidirectional Bands):")
print(f"  → {len(final_contour_closed)} contour points | Area = {area_your_method:.2f} m²")
# Out:
# Average spacing    d         : 0.1648 m
# Alpha-Shape  alpha = 4d      : 0.6591 m
# Ca-Alpha     alpha = 93×4d   : 61.2993 m
#
# Extracting Alpha-Shape (4d) ...
#   → 238 contour points | Area = 1002.10 m²
# Extracting Ca-Alpha (93×4d) ...
#   → 4 contour points | Area = 0.00 m²
#
# Your Method (Multidirectional Bands):
#   → 279 contour points | Area = 996.53 m²

# %%
# ============================================================================
# Cell C4: Side-by-Side Visual Comparison (1×3 Subplots)
# ============================================================================
def method_trace_points(pts_2d, name="Points", color="lightgray", size=2):
    """Scatter trace for original point cloud."""
    return go.Scatter(
        x=pts_2d[:, 0], y=pts_2d[:, 1],
        mode='markers',
        marker=dict(size=size, color=color, opacity=0.6),
        name=name, showlegend=False
    )


def method_trace_contour(contour, name, color, dash='solid', width=2.5):
    """Line+marker trace for an extracted contour."""
    if len(contour) == 0:
        return go.Scatter(x=[], y=[], name=name)
    return go.Scatter(
        x=contour[:, 0], y=contour[:, 1],
        mode='lines+markers',
        marker=dict(size=3, color=color),
        line=dict(color=color, width=width, dash=dash),
        name=name
    )


fig = make_subplots(
    rows=1, cols=3,
    subplot_titles=[
        f"<b>Your Method</b><br><sup>Multidirectional Bands (Wang et al. 2024)</sup><br>"
        f"<sup>{len(final_contour_closed)} pts | Area = {area_your_method:.2f} m²</sup>",

        f"<b>Alpha-Shape (4d)</b><br><sup>α = {alpha_4d:.4f} m</sup><br>"
        f"<sup>{len(contour_alpha_4d)} pts | Area = {area_alpha_4d:.2f} m²</sup>",

        f"<b>Ca-Alpha (93×4d)</b><br><sup>α = {alpha_ca_93_4d:.4f} m</sup><br>"
        f"<sup>{len(contour_ca_93_4d)} pts | Area = {area_ca_93_4d:.2f} m²</sup>",
    ],
    shared_xaxes=False, shared_yaxes=False,
    horizontal_spacing=0.06
)

# ── Panel 1: Your Method ─────────────────────────────────────────────────────
fig.add_trace(method_trace_points(points_2d, color='#94a3b8'), row=1, col=1)
fig.add_trace(method_trace_contour(
    final_contour_closed, 'Your Method', '#ef4444'), row=1, col=1)

# ── Panel 2: Alpha-Shape (4d) ────────────────────────────────────────────────
fig.add_trace(method_trace_points(points_2d, color='#94a3b8'), row=1, col=2)
fig.add_trace(method_trace_contour(
    contour_alpha_4d, 'Alpha-Shape 4d', '#3b82f6'), row=1, col=2)

# ── Panel 3: Ca-Alpha (93×4d) ────────────────────────────────────────────────
fig.add_trace(method_trace_points(points_2d, color='#94a3b8'), row=1, col=3)
fig.add_trace(method_trace_contour(
    contour_ca_93_4d, 'Ca-Alpha 93×4d', '#22c55e'), row=1, col=3)

fig.update_layout(
    title=dict(
        text='<b>Building Roof Contour Extraction — Method Comparison</b>',
        font=dict(size=18)
    ),
    height=550, width=1400,
    plot_bgcolor='#f8fafc',
    paper_bgcolor='white',
    showlegend=False,
    font=dict(family='Arial, sans-serif')
)

for i in range(1, 4):
    fig.update_xaxes(title_text='X (m)', showgrid=True,
                     gridcolor='#e2e8f0', row=1, col=i)
    fig.update_yaxes(title_text='Y (m)', showgrid=True,
                     gridcolor='#e2e8f0', scaleanchor=f'x{i if i>1 else ""}',
                     scaleratio=1, row=1, col=i)

fig.show()
print("✓ Side-by-side comparison rendered.")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# ============================================================================
# Cell C5: Overlay Comparison (All 3 Methods on One Plot)
# ============================================================================
fig2 = go.Figure()

# Original points (background)
fig2.add_trace(go.Scatter(
    x=points_2d[:, 0], y=points_2d[:, 1],
    mode='markers',
    marker=dict(size=2, color='#cbd5e1', opacity=0.5),
    name='Original Points'
))

# Ca-Alpha (93×4d) — drawn first so it's behind
if len(contour_ca_93_4d) > 0:
    fig2.add_trace(go.Scatter(
        x=contour_ca_93_4d[:, 0], y=contour_ca_93_4d[:, 1],
        mode='lines',
        line=dict(color='#22c55e', width=3, dash='dot'),
        name=f'Ca-Alpha (93×4d) | α={alpha_ca_93_4d:.2f}m | {len(contour_ca_93_4d)}pts | {area_ca_93_4d:.1f}m²'
    ))

# Alpha-Shape (4d)
if len(contour_alpha_4d) > 0:
    fig2.add_trace(go.Scatter(
        x=contour_alpha_4d[:, 0], y=contour_alpha_4d[:, 1],
        mode='lines',
        line=dict(color='#3b82f6', width=3, dash='dash'),
        name=f'Alpha-Shape (4d) | α={alpha_4d:.4f}m | {len(contour_alpha_4d)}pts | {area_alpha_4d:.1f}m²'
    ))

# Your Method — on top
fig2.add_trace(go.Scatter(
    x=final_contour_closed[:, 0], y=final_contour_closed[:, 1],
    mode='lines+markers',
    marker=dict(size=4, color='#ef4444'),
    line=dict(color='#ef4444', width=3),
    name=f'Your Method (Wang et al.) | {len(final_contour_closed)}pts | {area_your_method:.1f}m²'
))

fig2.update_layout(
    title='<b>All Methods Overlaid — Building Roof Contour Comparison</b>',
    xaxis_title='X (m)', yaxis_title='Y (m)',
    height=650, width=900,
    plot_bgcolor='#f8fafc',
    yaxis=dict(scaleanchor='x', scaleratio=1, showgrid=True, gridcolor='#e2e8f0'),
    xaxis=dict(showgrid=True, gridcolor='#e2e8f0'),
    legend=dict(
        x=0.01, y=0.01, bgcolor='rgba(255,255,255,0.9)',
        bordercolor='#e2e8f0', borderwidth=1,
        font=dict(size=11)
    ),
    font=dict(family='Arial, sans-serif')
)

fig2.show()
print("✓ Overlay comparison rendered.")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# ============================================================================
# Cell C6: Quantitative Comparison Summary Table
# ============================================================================
import pandas as pd

def edge_length_stats(contour):
    """Min, max, mean edge length of a closed polygon."""
    if len(contour) < 2:
        return dict(min=0, max=0, mean=0)
    edges = np.linalg.norm(np.diff(contour, axis=0), axis=1)
    return dict(
        min=float(edges.min()),
        max=float(edges.max()),
        mean=float(edges.mean())
    )

methods = [
    ('Your Method\n(Multidirectional Bands)',  final_contour_closed, '#ef4444'),
    (f'Alpha-Shape (4d)\nα={alpha_4d:.4f}m',  contour_alpha_4d,     '#3b82f6'),
    (f'Ca-Alpha (93×4d)\nα={alpha_ca_93_4d:.2f}m', contour_ca_93_4d, '#22c55e'),
]

rows = []
for label, contour, _ in methods:
    es = edge_length_stats(contour)
    rows.append({
        'Method'           : label.replace('\n', ' '),
        'Contour Points'   : len(contour),
        'Roof Area (m²)'   : round(compute_polygon_area(contour), 2),
        'Min Edge (m)'     : round(es['min'],  4),
        'Max Edge (m)'     : round(es['max'],  4),
        'Mean Edge (m)'    : round(es['mean'], 4),
    })

df = pd.DataFrame(rows).set_index('Method')

print("\n" + "="*75)
print("  QUANTITATIVE COMPARISON SUMMARY")
print("="*75)
print(df.to_string())
print("="*75)

# Styled display for Jupyter
df.style.set_caption("Method Comparison Summary") \
        .background_gradient(subset=['Contour Points', 'Roof Area (m²)'], cmap='RdYlGn') \
        .format(precision=4)
# Out:
# ...
#   QUANTITATIVE COMPARISON SUMMARY
# ...
#                                       Contour Points  Roof Area (m²)  Min Edge (m)  Max Edge (m)  Mean Edge (m)
# Method
# Your Method (Multidirectional Bands)             279          996.53        0.0199        1.6202         0.6441
# Alpha-Shape (4d) α=0.6591m                       238         1002.10        0.0663        1.6035         0.7400
# Ca-Alpha (93×4d) α=61.30m                          4            0.00        0.0197        0.0313         0.0247
# ...
# <style type="text/css">
# #T_9e96f_row0_col0, #T_9e96f_row1_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_9e96f_row0_col1 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_9e96f_row1_col0 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_9e96f_row2_col0, #T_9e96f_row2_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9e96f" class="dataframe">
#   <caption>Method Comparison Summary</caption>
#   <thead>
# ...

# %%
# ============================================================================
# Cell C7: Edge-Length Distribution Comparison (Histogram)
# ============================================================================
fig3 = go.Figure()

colors_hist = ['#ef4444', '#3b82f6', '#22c55e']
labels_hist = [
    'Your Method (Multidirectional Bands)',
    f'Alpha-Shape (4d | α={alpha_4d:.4f}m)',
    f'Ca-Alpha (93×4d | α={alpha_ca_93_4d:.2f}m)',
]
contours_hist = [final_contour_closed, contour_alpha_4d, contour_ca_93_4d]

for contour, color, label in zip(contours_hist, colors_hist, labels_hist):
    if len(contour) < 2:
        continue
    edges = np.linalg.norm(np.diff(contour, axis=0), axis=1)
    fig3.add_trace(go.Histogram(
        x=edges, name=label,
        marker_color=color, opacity=0.70,
        nbinsx=40
    ))

# Mark threshold T
fig3.add_vline(
    x=T, line_dash='dash', line_color='#f59e0b', line_width=2,
    annotation_text=f'T = 10d = {T:.4f}m', annotation_position='top right'
)

fig3.update_layout(
    title='<b>Edge Length Distribution per Method</b>',
    barmode='overlay',
    xaxis_title='Edge Length (m)',
    yaxis_title='Count',
    height=400, width=900,
    plot_bgcolor='#f8fafc',
    legend=dict(x=0.65, y=0.95),
    font=dict(family='Arial, sans-serif')
)
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# ============================================================================
# Cell C8: Final Comparison Report
# ============================================================================
print("\n" + "="*65)
print("  BUILDING CONTOUR EXTRACTION — FINAL COMPARISON REPORT")
print("="*65)
print(f"  Dataset:          build10.pts  ({len(points_2d)} points)")
print(f"  Avg spacing (d):  {avg_spacing:.4f} m")
print(f"  Band width  (W):  {W:.4f} m  (= 8d)")
print(f"  Threshold   (T):  {T:.4f} m  (= 10d)")
print()
print(f"  ① Your Method  (Multidirectional Bands, Wang et al. 2024)")
print(f"     Contour pts : {len(final_contour_closed)}")
print(f"     Roof area   : {area_your_method:.2f} m²")
print()
print(f"  ② Alpha-Shape  (α = 4d = {alpha_4d:.4f} m)")
print(f"     Contour pts : {len(contour_alpha_4d)}")
print(f"     Roof area   : {area_alpha_4d:.2f} m²")
print()
print(f"  ③ Ca-Alpha     (α = 93×4d = {alpha_ca_93_4d:.4f} m)")
print(f"     Contour pts : {len(contour_ca_93_4d)}")
print(f"     Roof area   : {area_ca_93_4d:.2f} m²")
print()
print("  Notes:")
print("  • Alpha-Shape (4d) — concave, detail-rich, may include noise.")
print("  • Ca-Alpha (93×4d) — smooth, coarser; approaches convex hull.")
print("  • Your method densifies via real point-cloud points (T=10d),")
print("    removing noise via elevation constraint (5d threshold).")
print("="*65)
print("\n✅ Comparison complete!")
# Out:
# ...
#   BUILDING CONTOUR EXTRACTION — FINAL COMPARISON REPORT
# ...
#   Dataset:          build10.pts  (9572 points)
#   Avg spacing (d):  0.1648 m
#   Band width  (W):  1.3183 m  (= 8d)
#   Threshold   (T):  1.6478 m  (= 10d)
#
#   ① Your Method  (Multidirectional Bands, Wang et al. 2024)
#      Contour pts : 279
#      Roof area   : 996.53 m²
#
#   ② Alpha-Shape  (α = 4d = 0.6591 m)
#      Contour pts : 238
#      Roof area   : 1002.10 m²
#
#   ③ Ca-Alpha     (α = 93×4d = 61.2993 m)
#      Contour pts : 4
#      Roof area   : 0.00 m²
#
#   Notes:
#   • Alpha-Shape (4d) — concave, detail-rich, may include noise.
#   • Ca-Alpha (93×4d) — smooth, coarser; approaches convex hull.
#   • Your method densifies via real point-cloud points (T=10d),
#     removing noise via elevation constraint (5d threshold).
# ...
#
# ✅ Comparison complete!

# %%
# ============================================================================
# COMPARISON METHODS IMPLEMENTATION
# Add these cells to your notebook after the existing code
# ============================================================================

# Cell 1: Alpha Shapes Method (Paper baseline)
# ============================================================================
print("="*60)
print("IMPLEMENTING COMPARISON METHODS")
print("="*60)

def extract_contour_alpha_shapes(points_2d, alpha_value):
    """
    Traditional Alpha Shapes method with fixed rolling ball radius.

    Paper comparison: α-shape(2d) and α-shape(4d)
    - Uses fixed radius r based on average spacing
    - Sensitive to density variations
    - May extract internal holes
    """
    try:
        alpha_shape = alphashape.alphashape(points_2d, alpha_value)

        # Extract coordinates
        if isinstance(alpha_shape, Polygon):
            contour = np.array(alpha_shape.exterior.coords)
        elif isinstance(alpha_shape, MultiPolygon):
            # Take largest polygon if multiple
            largest = max(alpha_shape.geoms, key=lambda p: p.area)
            contour = np.array(largest.exterior.coords)
        else:
            contour = np.array([])

        return contour
    except Exception as e:
        print(f"Alpha shapes failed: {e}")
        return np.array([])

# Test with paper-specified parameters
alpha_2d = 1.0 / (2 * avg_spacing)  # r = 2d
alpha_4d = 1.0 / (4 * avg_spacing)  # r = 4d

print(f"\nExtracting Alpha Shapes contours...")
contour_alpha_2d = extract_contour_alpha_shapes(points_2d, alpha_2d)
contour_alpha_4d = extract_contour_alpha_shapes(points_2d, alpha_4d)

print(f"✓ α-shape(2d): {len(contour_alpha_2d)} points")
print(f"✓ α-shape(4d): {len(contour_alpha_4d)} points")
# Out:
# ...
# IMPLEMENTING COMPARISON METHODS
# ...
#
# Extracting Alpha Shapes contours...
# ✓ α-shape(2d): 760 points
# ✓ α-shape(4d): 349 points

# %%
# Cell 2: Variable-Radius Alpha Shapes Method
# ============================================================================
def extract_contour_variable_alpha(points_2d, avg_spacing, min_factor=2, max_factor=4, grid_size=20):
    """
    Variable-radius Alpha Shapes method (Cα-shape).

    Paper comparison: Cα-shape(2-3d) and Cα-shape(3-4d)
    - Divides points into grid
    - Adapts radius based on local density
    - Better handles density variations but may extract holes in boundary grids
    """
    # Create virtual grid
    x_min, y_min = points_2d.min(axis=0)
    x_max, y_max = points_2d.max(axis=0)

    x_bins = np.linspace(x_min, x_max, grid_size)
    y_bins = np.linspace(y_min, y_max, grid_size)

    # Assign points to grid cells
    grid_points = {}
    for point in points_2d:
        x_idx = np.digitize(point[0], x_bins) - 1
        y_idx = np.digitize(point[1], y_bins) - 1
        key = (x_idx, y_idx)

        if key not in grid_points:
            grid_points[key] = []
        grid_points[key].append(point)

    # Calculate local density for each grid
    grid_alphas = {}
    for key, pts in grid_points.items():
        if len(pts) < 3:
            continue

        # Calculate local spacing
        pts_array = np.array(pts)
        if len(pts_array) > 1:
            tree = cKDTree(pts_array)
            distances, _ = tree.query(pts_array, k=min(2, len(pts_array)))
            local_spacing = np.mean(distances[:, -1]) if len(pts_array) > 1 else avg_spacing
        else:
            local_spacing = avg_spacing

        # Adaptive radius between min_factor and max_factor
        radius_factor = min_factor + (max_factor - min_factor) * (local_spacing / avg_spacing)
        grid_alphas[key] = 1.0 / (radius_factor * local_spacing)

    # Apply alpha shapes with adaptive radius
    all_contours = []
    for key, pts in grid_points.items():
        if len(pts) < 3 or key not in grid_alphas:
            continue

        try:
            shape = alphashape.alphashape(pts, grid_alphas[key])
            if isinstance(shape, Polygon):
                coords = np.array(shape.exterior.coords)
                all_contours.append(coords)
            elif isinstance(shape, MultiPolygon):
                for poly in shape.geoms:
                    coords = np.array(poly.exterior.coords)
                    all_contours.append(coords)
        except:
            continue

    if not all_contours:
        # Fallback to simple alpha shapes
        return extract_contour_alpha_shapes(points_2d, 1.0 / (3 * avg_spacing))

    # Merge all contours and extract outer boundary
    all_points = np.vstack(all_contours)
    unique_points = np.unique(np.round(all_points, decimals=6), axis=0)

    # Final alpha shapes on merged points
    final_alpha = 1.0 / ((min_factor + max_factor) / 2 * avg_spacing)
    final_contour = extract_contour_alpha_shapes(unique_points, final_alpha)

    return final_contour

# Test with paper-specified parameters
print(f"\nExtracting Variable-radius Alpha Shapes contours...")
contour_var_alpha_2_3d = extract_contour_variable_alpha(points_2d, avg_spacing, min_factor=2, max_factor=3)
contour_var_alpha_3_4d = extract_contour_variable_alpha(points_2d, avg_spacing, min_factor=3, max_factor=4)

print(f"✓ Cα-shape(2-3d): {len(contour_var_alpha_2_3d)} points")
print(f"✓ Cα-shape(3-4d): {len(contour_var_alpha_3_4d)} points")
# Out:
# Extracting Variable-radius Alpha Shapes contours...
# ✓ Cα-shape(2-3d): 734 points
# ✓ Cα-shape(3-4d): 531 points

# %%
# Cell 3: Evaluation Metrics - PoLiS Measurement
# ============================================================================
def calculate_polis(contour_a, contour_b):
    """
    Calculate PoLiS (Polygon Similarity) measurement.

    Paper equation (5):
    PoLiS(A,B) = 1/(2p) Σ min||ai - b|| + 1/(2q) Σ min||bj - a||

    Measures similarity between two polygons.
    Lower value = better similarity.
    """
    if len(contour_a) == 0 or len(contour_b) == 0:
        return np.inf

    # Ensure contours are closed
    if not np.allclose(contour_a[0], contour_a[-1]):
        contour_a = np.vstack([contour_a, contour_a[0]])
    if not np.allclose(contour_b[0], contour_b[-1]):
        contour_b = np.vstack([contour_b, contour_b[0]])

    p = len(contour_a)
    q = len(contour_b)

    # For each point in A, find minimum distance to any point in B
    distances_a_to_b = cdist(contour_a, contour_b, metric='euclidean')
    min_dist_a = np.min(distances_a_to_b, axis=1)
    sum_a = np.sum(min_dist_a)

    # For each point in B, find minimum distance to any point in A
    min_dist_b = np.min(distances_a_to_b, axis=0)
    sum_b = np.sum(min_dist_b)

    polis = (sum_a / (2 * p)) + (sum_b / (2 * q))

    return polis

# %%
# Cell 4: Evaluation Metrics - RAE (Relative Area Error)
# ============================================================================
def calculate_rae(contour_extracted, contour_reference):
    """
    Calculate Relative Area Error (RAE).

    Paper equation (6):
    RAE = |Area_extracted - Area_reference| / Area_reference × 100%

    Measures area difference between extracted and reference contour.
    Lower value = better accuracy.
    """
    try:
        # Convert to Shapely polygons
        if not np.allclose(contour_extracted[0], contour_extracted[-1]):
            contour_extracted = np.vstack([contour_extracted, contour_extracted[0]])
        if not np.allclose(contour_reference[0], contour_reference[-1]):
            contour_reference = np.vstack([contour_reference, contour_reference[0]])

        poly_extracted = Polygon(contour_extracted)
        poly_reference = Polygon(contour_reference)

        area_extracted = poly_extracted.area
        area_reference = poly_reference.area

        if area_reference == 0:
            return np.inf

        rae = abs(area_extracted - area_reference) / area_reference * 100

        return rae
    except Exception as e:
        print(f"RAE calculation error: {e}")
        return np.inf

# %%
# Cell 5: Create Reference Contour (Manual or Alpha Shapes)
# ============================================================================
def create_reference_contour(points_2d, method='convex_hull'):
    """
    Create reference contour for comparison.

    Options:
    - 'convex_hull': Use convex hull as reference
    - 'fine_alpha': Use very fine alpha shapes
    - 'manual': Load manually created reference (if available)
    """
    if method == 'convex_hull':
        from scipy.spatial import ConvexHull
        hull = ConvexHull(points_2d)
        reference = points_2d[hull.vertices]

    elif method == 'fine_alpha':
        # Use very fine alpha value
        fine_alpha = 1.0 / (1.5 * avg_spacing)
        reference = extract_contour_alpha_shapes(points_2d, fine_alpha)

    else:
        # Use alpha shapes with r=2d as baseline
        reference = contour_alpha_2d

    return reference

# Create reference contour
reference_contour = create_reference_contour(points_2d, method='fine_alpha')
print(f"\n✓ Reference contour created: {len(reference_contour)} points")
# Out:
# ✓ Reference contour created: 691 points

# %%
# Cell 6: Calculate Metrics for All Methods
# ============================================================================
print("\n" + "="*60)
print("EVALUATION METRICS")
print("="*60)

methods = {
    'α-shape(2d)': contour_alpha_2d,
    'α-shape(4d)': contour_alpha_4d,
    'Cα-shape(2-3d)': contour_var_alpha_2_3d,
    'Cα-shape(3-4d)': contour_var_alpha_3_4d,
    'Multidirectional (Ours)': final_contour_closed
}

results = []

for method_name, contour in methods.items():
    if len(contour) == 0:
        continue

    polis = calculate_polis(contour, reference_contour)
    rae = calculate_rae(contour, reference_contour)
    num_points = len(contour)

    results.append({
        'Method': method_name,
        'Points': num_points,
        'PoLiS (m)': round(polis, 4),
        'RAE (%)': round(rae, 2)
    })

    print(f"\n{method_name}:")
    print(f"  Points: {num_points}")
    print(f"  PoLiS: {polis:.4f} m")
    print(f"  RAE: {rae:.2f}%")

print("="*60)
# Out:
# ...
# EVALUATION METRICS
# ...
#
# α-shape(2d):
#   Points: 760
#   PoLiS: 8.2828 m
#   RAE: 388.55%
#
# α-shape(4d):
#   Points: 349
#   PoLiS: 9.6958 m
#   RAE: 508.31%
#
# Cα-shape(2-3d):
#   Points: 734
#   PoLiS: 4.2604 m
#   RAE: 183.50%
#
# Cα-shape(3-4d):
#   Points: 531
#   PoLiS: 9.1480 m
#   RAE: 437.04%
#
# Multidirectional (Ours):
#   Points: 279
#   PoLiS: 9.3925 m
#   RAE: 510.19%
# ...

# %%
# Cell 7: Performance Timing Comparison
# ============================================================================
import time

print("\n" + "="*60)
print("PERFORMANCE COMPARISON")
print("="*60)

timing_results = []

# Time Alpha Shapes (2d)
start = time.time()
_ = extract_contour_alpha_shapes(points_2d, alpha_2d)
time_alpha_2d = time.time() - start

# Time Alpha Shapes (4d)
start = time.time()
_ = extract_contour_alpha_shapes(points_2d, alpha_4d)
time_alpha_4d = time.time() - start

# Time Variable Alpha (2-3d)
start = time.time()
_ = extract_contour_variable_alpha(points_2d, avg_spacing, min_factor=2, max_factor=3)
time_var_2_3d = time.time() - start

# Time Variable Alpha (3-4d)
start = time.time()
_ = extract_contour_variable_alpha(points_2d, avg_spacing, min_factor=3, max_factor=4)
time_var_3_4d = time.time() - start

# Time Multidirectional method (run full pipeline)
start = time.time()
temp_multi = extract_contour_multidirectional(points_2d, W)
temp_sorted = sort_contour_points_with_constraint(temp_multi, beta_degrees=240)
temp_densified = densify_contour_paper_method(temp_sorted, points_2d, T)
temp_final = remove_noise_points(temp_densified, points_3d, avg_spacing)
time_multidirectional = time.time() - start

timing_results = [
    ('α-shape(2d)', time_alpha_2d),
    ('α-shape(4d)', time_alpha_4d),
    ('Cα-shape(2-3d)', time_var_2_3d),
    ('Cα-shape(3-4d)', time_var_3_4d),
    ('Multidirectional (Ours)', time_multidirectional)
]

for method, exec_time in timing_results:
    print(f"{method:25s}: {exec_time:.4f} seconds")

print("="*60)
# Out:
# ...
# PERFORMANCE COMPARISON
# ...
# Extracting contour in 6 directions...
#   0°: 62 points
#   30°: 101 points
#   60°: 114 points
#   90°: 111 points
#   120°: 84 points
#   150°: 37 points
# Densifying long edges...
#   Iteration 1: Inserted point, edge length 1.8305 → split
#   Converged after 2 iterations
# ✓ Removed 0 noise points (threshold: 0.8239m)
# α-shape(2d)              : 2.8689 seconds
# α-shape(4d)              : 4.1375 seconds
# Cα-shape(2-3d)           : 3.3111 seconds
# Cα-shape(3-4d)           : 3.3179 seconds
# Multidirectional (Ours)  : 0.4698 seconds
# ...

# %%
 #Cell 8: Comprehensive Comparison Visualization
# ============================================================================
def visualize_all_methods_comparison(points_2d, methods_dict):
    """
    Create side-by-side comparison of all methods
    """
    fig = go.Figure()

    # Original points (gray background)
    fig.add_trace(go.Scatter(
        x=points_2d[:, 0],
        y=points_2d[:, 1],
        mode='markers',
        marker=dict(size=1.5, color='lightgray', opacity=0.3),
        name='Original Points',
        showlegend=True
    ))

    colors = ['blue', 'cyan', 'orange', 'yellow', 'red']

    for (method_name, contour), color in zip(methods_dict.items(), colors):
        if len(contour) == 0:
            continue

        fig.add_trace(go.Scatter(
            x=contour[:, 0],
            y=contour[:, 1],
            mode='lines+markers',
            marker=dict(size=3, color=color),
            line=dict(width=2, color=color),
            name=method_name,
            visible='legendonly' if method_name != 'Multidirectional (Ours)' else True
        ))

    fig.update_layout(
        title='Method Comparison: Click legend to toggle methods',
        xaxis_title='X (m)',
        yaxis_title='Y (m)',
        hovermode='closest',
        height=700,
        legend=dict(
            yanchor="top",
            y=0.99,
            xanchor="left",
            x=0.01
        )
    )

    fig.show()

# Visualize comparison
visualize_all_methods_comparison(points_2d, methods)


# Cell 9: Create Comparison Table
# ============================================================================
import pandas as pd

# Create comprehensive comparison table
comparison_df = pd.DataFrame(results)

# Add timing information
timing_dict = {name: time for name, time in timing_results}
comparison_df['Time (s)'] = comparison_df['Method'].map(timing_dict).round(4)

# Reorder columns
comparison_df = comparison_df[['Method', 'Points', 'PoLiS (m)', 'RAE (%)', 'Time (s)']]

print("\n" + "="*60)
print("COMPREHENSIVE COMPARISON TABLE")
print("="*60)
print(comparison_df.to_string(index=False))
print("="*60)

# Highlight best results
print("\nBEST RESULTS:")
print(f"  Lowest PoLiS: {comparison_df.loc[comparison_df['PoLiS (m)'].idxmin(), 'Method']}")
print(f"  Lowest RAE: {comparison_df.loc[comparison_df['RAE (%)'].idxmin(), 'Method']}")
print(f"  Fastest: {comparison_df.loc[comparison_df['Time (s)'].idxmin(), 'Method']}")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Cell 11: Edge Length Distribution Comparison
# ============================================================================
def analyze_edge_lengths(contour, method_name):
    """
    Analyze distribution of edge lengths in contour
    """
    if len(contour) < 2:
        return None

    edges = []
    for i in range(len(contour) - 1):
        length = np.linalg.norm(contour[i+1] - contour[i])
        edges.append(length)

    return {
        'method': method_name,
        'mean': np.mean(edges),
        'std': np.std(edges),
        'min': np.min(edges),
        'max': np.max(edges),
        'median': np.median(edges)
    }

print("\n" + "="*60)
print("EDGE LENGTH ANALYSIS")
print("="*60)

edge_stats = []
for method_name, contour in methods.items():
    if len(contour) > 0:
        stats = analyze_edge_lengths(contour, method_name)
        if stats:
            edge_stats.append(stats)
            print(f"\n{method_name}:")
            print(f"  Mean: {stats['mean']:.4f} m")
            print(f"  Std: {stats['std']:.4f} m")
            print(f"  Min: {stats['min']:.4f} m")
            print(f"  Max: {stats['max']:.4f} m")
            print(f"  Median: {stats['median']:.4f} m")

print("="*60)
# Out:
# ...
# EDGE LENGTH ANALYSIS
# ...
#
# α-shape(2d):
#   Mean: 0.3739 m
#   Std: 0.1591 m
#   Min: 0.0199 m
#   Max: 0.6526 m
#   Median: 0.3728 m
#
# α-shape(4d):
#   Mean: 0.5186 m
#   Std: 0.2599 m
#   Min: 0.0294 m
#   Max: 1.1388 m
#   Median: 0.5210 m
#
# Cα-shape(2-3d):
#   Mean: 0.4654 m
#   Std: 0.1838 m
#   Min: 0.0305 m
#   Max: 0.8193 m
#   Median: 0.4821 m
#
# Cα-shape(3-4d):
#   Mean: 0.5731 m
#   Std: 0.2700 m
#   Min: 0.0294 m
#   Max: 1.1300 m
#   Median: 0.5781 m
#
# Multidirectional (Ours):
#   Mean: 0.6441 m
#   Std: 0.3474 m
#   Min: 0.0199 m
#   Max: 1.6202 m
#   Median: 0.6046 m
# ...

# %%
#===========================================================================
# AREA CALCULATION AND COMPARISON
# Add these cells to your notebook for comprehensive area analysis
# ============================================================================

# Cell 1: Calculate Areas for All Methods
# ============================================================================
from shapely.geometry import Polygon
from shapely.validation import make_valid
import matplotlib.pyplot as plt

def calculate_polygon_area(contour):
    """
    Calculate area of a contour polygon.

    Returns:
    - area: Area in square meters
    - perimeter: Perimeter in meters
    - is_valid: Whether polygon is geometrically valid
    """
    try:
        # Ensure contour is closed
        if len(contour) < 3:
            return 0.0, 0.0, False

        if not np.allclose(contour[0], contour[-1], atol=1e-6):
            contour = np.vstack([contour, contour[0]])

        # Create polygon
        poly = Polygon(contour)

        # Check if valid
        if not poly.is_valid:
            poly = make_valid(poly)

        area = poly.area
        perimeter = poly.length

        return area, perimeter, poly.is_valid

    except Exception as e:
        print(f"Error calculating area: {e}")
        return 0.0, 0.0, False


print("="*70)
print("AREA CALCULATION FOR ALL METHODS")
print("="*70)

# Calculate areas for all methods
area_results = {}

methods_with_contours = {
    'α-shape(2d)': contour_alpha_2d,
    'α-shape(4d)': contour_alpha_4d,
    'Cα-shape(2-3d)': contour_var_alpha_2_3d,
    'Cα-shape(3-4d)': contour_var_alpha_3_4d,
    'Multidirectional (Ours)': final_contour_closed,
    'Reference': reference_contour
}

for method_name, contour in methods_with_contours.items():
    if len(contour) > 0:
        area, perimeter, is_valid = calculate_polygon_area(contour)
        area_results[method_name] = {
            'area': area,
            'perimeter': perimeter,
            'is_valid': is_valid,
            'points': len(contour)
        }

        print(f"\n{method_name}:")
        print(f"  Area: {area:.2f} m²")
        print(f"  Perimeter: {perimeter:.2f} m")
        print(f"  Valid: {is_valid}")
    else:
        print(f"\n{method_name}: No contour extracted")

print("="*70)
# Out:
# ...
# AREA CALCULATION FOR ALL METHODS
# ...
#
# α-shape(2d):
#   Area: 797.89 m²
#   Perimeter: 283.78 m
#   Valid: True
#
# α-shape(4d):
#   Area: 993.47 m²
#   Perimeter: 180.47 m
#   Valid: True
#
# Cα-shape(2-3d):
#   Area: 463.00 m²
#   Perimeter: 341.14 m
#   Valid: True
#
# Cα-shape(3-4d):
#   Area: 877.07 m²
#   Perimeter: 303.75 m
#   Valid: True
#
# Multidirectional (Ours):
#   Area: 996.53 m²
#   Perimeter: 179.07 m
#   Valid: True
#
# Reference:
#   Area: 163.32 m²
#   Perimeter: 213.94 m
#   Valid: True
# ...

# %%
# Cell 2: Calculate Area Differences from Reference
# ============================================================================
print("\n" + "="*70)
print("AREA COMPARISON WITH REFERENCE")
print("="*70)

reference_area = area_results['Reference']['area']
print(f"Reference Area: {reference_area:.2f} m²\n")

area_comparison = []

for method_name in ['α-shape(2d)', 'α-shape(4d)', 'Cα-shape(2-3d)',
                     'Cα-shape(3-4d)', 'Multidirectional (Ours)']:
    if method_name in area_results:
        method_area = area_results[method_name]['area']

        # Calculate differences
        absolute_diff = abs(method_area - reference_area)
        relative_diff = (absolute_diff / reference_area) * 100 if reference_area > 0 else 0
        percentage_of_ref = (method_area / reference_area) * 100 if reference_area > 0 else 0

        area_comparison.append({
            'Method': method_name,
            'Area (m²)': round(method_area, 2),
            'Absolute Diff (m²)': round(absolute_diff, 2),
            'Relative Error (%)': round(relative_diff, 2),
            'Of Reference (%)': round(percentage_of_ref, 2)
        })

        print(f"{method_name}:")
        print(f"  Area: {method_area:.2f} m²")
        print(f"  Difference: {absolute_diff:.2f} m² ({relative_diff:.2f}%)")
        print(f"  Percentage of reference: {percentage_of_ref:.2f}%")

        # Show if over/under estimated
        if method_area > reference_area:
            print(f"  Status: OVERESTIMATED by {absolute_diff:.2f} m²")
        else:
            print(f"  Status: UNDERESTIMATED by {absolute_diff:.2f} m²")
        print()

print("="*70)
# Out:
# ...
# AREA COMPARISON WITH REFERENCE
# ...
# Reference Area: 163.32 m²
#
# α-shape(2d):
#   Area: 797.89 m²
#   Difference: 634.57 m² (388.55%)
#   Percentage of reference: 488.55%
#   Status: OVERESTIMATED by 634.57 m²
#
# α-shape(4d):
#   Area: 993.47 m²
#   Difference: 830.15 m² (508.31%)
#   Percentage of reference: 608.31%
#   Status: OVERESTIMATED by 830.15 m²
#
# Cα-shape(2-3d):
#   Area: 463.00 m²
#   Difference: 299.68 m² (183.50%)
#   Percentage of reference: 283.50%
#   Status: OVERESTIMATED by 299.68 m²
#
# Cα-shape(3-4d):
#   Area: 877.07 m²
#   Difference: 713.76 m² (437.04%)
#   Percentage of reference: 537.04%
#   Status: OVERESTIMATED by 713.76 m²
#
# Multidirectional (Ours):
#   Area: 996.53 m²
#   Difference: 833.22 m² (510.19%)
#   Percentage of reference: 610.19%
#   Status: OVERESTIMATED by 833.22 m²
#
# ...

# %%
# Cell 3: Create Area Comparison DataFrame
# ============================================================================
import pandas as pd

area_df = pd.DataFrame(area_comparison)
area_df = area_df.sort_values('Relative Error (%)')

print("\n" + "="*70)
print("AREA COMPARISON TABLE (Sorted by Relative Error)")
print("="*70)
print(area_df.to_string(index=False))
print("="*70)

# Highlight best method
best_method = area_df.iloc[0]['Method']
best_error = area_df.iloc[0]['Relative Error (%)']
print(f"\n✓ Most Accurate: {best_method} (Error: {best_error}%)")
# Out:
# ...
# AREA COMPARISON TABLE (Sorted by Relative Error)
# ...
#                  Method  Area (m²)  Absolute Diff (m²)  Relative Error (%)  Of Reference (%)
#          Cα-shape(2-3d)     463.00              299.68              183.50            283.50
#             α-shape(2d)     797.89              634.57              388.55            488.55
#          Cα-shape(3-4d)     877.07              713.76              437.04            537.04
#             α-shape(4d)     993.47              830.15              508.31            608.31
# Multidirectional (Ours)     996.53              833.22              510.19            610.19
# ...
#
# ✓ Most Accurate: Cα-shape(2-3d) (Error: 183.5%)

# %%
# Cell 4: Visualize Area Comparison (Bar Chart)
# ============================================================================
def visualize_area_comparison_bar(area_comparison, reference_area):
    """
    Create bar chart comparing areas of all methods
    """
    methods = [item['Method'] for item in area_comparison]
    areas = [item['Area (m²)'] for item in area_comparison]

    # Create figure
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

    # Plot 1: Absolute Areas
    colors = ['blue', 'cyan', 'orange', 'yellow', 'red']
    bars1 = ax1.bar(range(len(methods)), areas, color=colors, alpha=0.7, edgecolor='black')
    ax1.axhline(y=reference_area, color='green', linestyle='--', linewidth=2, label='Reference')
    ax1.set_xlabel('Method', fontsize=12, fontweight='bold')
    ax1.set_ylabel('Area (m²)', fontsize=12, fontweight='bold')
    ax1.set_title('Absolute Area Comparison', fontsize=14, fontweight='bold')
    ax1.set_xticks(range(len(methods)))
    ax1.set_xticklabels(methods, rotation=45, ha='right')
    ax1.legend()
    ax1.grid(axis='y', alpha=0.3)

    # Add value labels on bars
    for i, (bar, area) in enumerate(zip(bars1, areas)):
        height = bar.get_height()
        ax1.text(bar.get_x() + bar.get_width()/2., height,
                f'{area:.1f}m²',
                ha='center', va='bottom', fontsize=9, fontweight='bold')

    # Plot 2: Relative Error
    errors = [item['Relative Error (%)'] for item in area_comparison]
    bars2 = ax2.bar(range(len(methods)), errors, color=colors, alpha=0.7, edgecolor='black')
    ax2.set_xlabel('Method', fontsize=12, fontweight='bold')
    ax2.set_ylabel('Relative Error (%)', fontsize=12, fontweight='bold')
    ax2.set_title('Relative Area Error', fontsize=14, fontweight='bold')
    ax2.set_xticks(range(len(methods)))
    ax2.set_xticklabels(methods, rotation=45, ha='right')
    ax2.grid(axis='y', alpha=0.3)

    # Add value labels on bars
    for bar, error in zip(bars2, errors):
        height = bar.get_height()
        ax2.text(bar.get_x() + bar.get_width()/2., height,
                f'{error:.2f}%',
                ha='center', va='bottom', fontsize=9, fontweight='bold')

    plt.tight_layout()
    plt.show()

visualize_area_comparison_bar(area_comparison, reference_area)

# %%
# Cell 5: Visualize Area with Plotly (Interactive)
# ============================================================================
def visualize_area_comparison_interactive(area_comparison, reference_area):
    """
    Create interactive area comparison visualization
    """
    methods = [item['Method'] for item in area_comparison]
    areas = [item['Area (m²)'] for item in area_comparison]
    errors = [item['Relative Error (%)'] for item in area_comparison]

    # Create subplots
    from plotly.subplots import make_subplots

    fig = make_subplots(
        rows=1, cols=2,
        subplot_titles=('Area Comparison', 'Relative Error'),
        specs=[[{"type": "bar"}, {"type": "bar"}]]
    )

    # Add area bars
    fig.add_trace(
        go.Bar(
            x=methods,
            y=areas,
            name='Area (m²)',
            marker_color=['blue', 'cyan', 'orange', 'yellow', 'red'],
            text=[f'{a:.2f}m²' for a in areas],
            textposition='outside'
        ),
        row=1, col=1
    )

    # Add reference line
    fig.add_hline(
        y=reference_area,
        line_dash="dash",
        line_color="green",
        annotation_text=f"Reference: {reference_area:.2f}m²",
        row=1, col=1
    )

    # Add error bars
    fig.add_trace(
        go.Bar(
            x=methods,
            y=errors,
            name='Error (%)',
            marker_color=['blue', 'cyan', 'orange', 'yellow', 'red'],
            text=[f'{e:.2f}%' for e in errors],
            textposition='outside'
        ),
        row=1, col=2
    )

    fig.update_xaxes(tickangle=45, row=1, col=1)
    fig.update_xaxes(tickangle=45, row=1, col=2)
    fig.update_yaxes(title_text="Area (m²)", row=1, col=1)
    fig.update_yaxes(title_text="Relative Error (%)", row=1, col=2)

    fig.update_layout(
        title_text="Area Comparison: All Methods",
        showlegend=False,
        height=500
    )

    fig.show()

visualize_area_comparison_interactive(area_comparison, reference_area)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Cell 6: Overlay Visualization with Area Information
# ============================================================================
def visualize_contours_with_area(points_2d, methods_dict, area_results):
    """
    Visualize all contours with area information in legend
    """
    fig = go.Figure()

    # Original points
    fig.add_trace(go.Scatter(
        x=points_2d[:, 0],
        y=points_2d[:, 1],
        mode='markers',
        marker=dict(size=1.5, color='lightgray', opacity=0.3),
        name='Original Points',
        showlegend=True
    ))

    colors = ['blue', 'cyan', 'orange', 'yellow', 'red', 'green']
    method_names = list(methods_dict.keys())

    for method_name, color in zip(method_names, colors):
        contour = methods_dict[method_name]
        if len(contour) == 0:
            continue

        area = area_results.get(method_name, {}).get('area', 0)

        fig.add_trace(go.Scatter(
            x=contour[:, 0],
            y=contour[:, 1],
            mode='lines',
            line=dict(width=2, color=color),
            name=f'{method_name} ({area:.2f}m²)',
            visible='legendonly' if method_name == 'Reference' else True
        ))

    fig.update_layout(
        title='Contour Comparison with Area Information<br><sub>Click legend to toggle methods</sub>',
        xaxis_title='X (m)',
        yaxis_title='Y (m)',
        hovermode='closest',
        height=700,
        legend=dict(
            yanchor="top",
            y=0.99,
            xanchor="left",
            x=0.01,
            bgcolor="rgba(255,255,255,0.8)"
        )
    )

    fig.show()

visualize_contours_with_area(points_2d, methods_with_contours, area_results)


# Cell 7: Statistical Analysis of Area Accuracy
# ============================================================================
print("\n" + "="*70)
print("STATISTICAL ANALYSIS")
print("="*70)

# Calculate statistics
areas_only = [item['Area (m²)'] for item in area_comparison]
errors_only = [item['Relative Error (%)'] for item in area_comparison]

print(f"\nArea Statistics:")
print(f"  Mean Area: {np.mean(areas_only):.2f} m²")
print(f"  Std Dev: {np.std(areas_only):.2f} m²")
print(f"  Min Area: {np.min(areas_only):.2f} m²")
print(f"  Max Area: {np.max(areas_only):.2f} m²")
print(f"  Range: {np.max(areas_only) - np.min(areas_only):.2f} m²")

print(f"\nError Statistics:")
print(f"  Mean Error: {np.mean(errors_only):.2f}%")
print(f"  Std Dev: {np.std(errors_only):.2f}%")
print(f"  Min Error: {np.min(errors_only):.2f}%")
print(f"  Max Error: {np.max(errors_only):.2f}%")

# Paper claims
print(f"\n📄 Paper Claims:")
print(f"  RAE < 7% ✓ (Target)")
print(f"  PoLiS < 0.2m ✓ (Target)")

# Check if our method meets paper claims
our_method_error = next(item['Relative Error (%)'] for item in area_comparison
                        if item['Method'] == 'Multidirectional (Ours)')

print(f"\n🎯 Our Method Performance:")
print(f"  Relative Error: {our_method_error:.2f}%")
if our_method_error < 7:
    print(f"  Status: ✓ MEETS paper claim (< 7%)")
else:
    print(f"  Status: ✗ Does not meet paper claim")

print("="*70)


# Cell 8: Create Comprehensive Results Table
# ============================================================================
# Merge all metrics into one comprehensive table
comprehensive_results = []

for method_name in ['α-shape(2d)', 'α-shape(4d)', 'Cα-shape(2-3d)',
                     'Cα-shape(3-4d)', 'Multidirectional (Ours)']:

    # Get area data
    area_data = next((item for item in area_comparison if item['Method'] == method_name), None)

    # Get PoLiS and timing data from previous results
    result_data = next((item for item in results if item['Method'] == method_name), None)

    if area_data and result_data:
        comprehensive_results.append({
            'Method': method_name,
            'Points': result_data['Points'],
            'Area (m²)': area_data['Area (m²)'],
            'Area Error (%)': area_data['Relative Error (%)'],
            'PoLiS (m)': result_data['PoLiS (m)'],
            'RAE (%)': result_data['RAE (%)'],
            'Time (s)': result_data.get('Time (s)', 0)
        })

comprehensive_df = pd.DataFrame(comprehensive_results)

print("\n" + "="*70)
print("COMPREHENSIVE COMPARISON TABLE")
print("="*70)
print(comprehensive_df.to_string(index=False))
print("="*70)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
